# %%
import pickle
from xgboost import to_graphviz

# 1. Load the trained XGBoost model and the LabelEncoder
with open('xgboost_model.pkl', 'rb') as f:
    model = pickle.load(f)

with open('label_encoder.pkl', 'rb') as f:
    label_encoder = pickle.load(f)

# Retrieve class labels from the encoder
classes = label_encoder.classes_ if hasattr(label_encoder, 'classes_') else label_encoder
num_classes = len(classes)

# 2. Access the underlying booster and compute total number of trees
booster = model.get_booster()

# multiply number of boosting rounds by number of classes
num_rounds = booster.num_boosted_rounds()
total_trees = num_rounds * num_classes
1
print(f"Boosting rounds: {num_rounds}")
print(f"Number of classes: {num_classes}")
print(f"Total trees to render: {total_trees}\n")

# 3. Iterate and render each tree, embedding the class name in the filename
for i in range(total_trees):
    cls = classes[i % num_classes]
    print(f"Rendering tree {i} for class '{cls}'")

    # Generate the graphviz object for tree i
    dot = to_graphviz(booster, num_trees=i)

    # Filename includes tree index and class label
    output_filename = f"tree_{i}_{cls}"

    # Save as PDF (e.g., tree_0_ClassA.pdf, tree_1_ClassB.pdf, ...)
    dot.render(output_filename)

print("\nAll trees have been rendered with class names in their filenames.")
# Out:
# Boosting rounds: 20
# Number of classes: 6
# Total trees to render: 120
#
# Rendering tree 0 for class 'TCP500Mbps'
# Rendering tree 1 for class 'TCP50Mbps'
# Rendering tree 2 for class 'TCP5Mbps'
# Rendering tree 3 for class 'UDP500Mbps'
# Rendering tree 4 for class 'UDP50Mbps'
# Rendering tree 5 for class 'UDP5Mbps'
# Rendering tree 6 for class 'TCP500Mbps'
# Rendering tree 7 for class 'TCP50Mbps'
# Rendering tree 8 for class 'TCP5Mbps'
# Rendering tree 9 for class 'UDP500Mbps'
# Rendering tree 10 for class 'UDP50Mbps'
# Rendering tree 11 for class 'UDP5Mbps'
# Rendering tree 12 for class 'TCP500Mbps'
# Rendering tree 13 for class 'TCP50Mbps'
# Rendering tree 14 for class 'TCP5Mbps'
# Rendering tree 15 for class 'UDP500Mbps'
# Rendering tree 16 for class 'UDP50Mbps'
# Rendering tree 17 for class 'UDP5Mbps'
# Rendering tree 18 for class 'TCP500Mbps'
# Rendering tree 19 for class 'TCP50Mbps'
# Rendering tree 20 for class 'TCP5Mbps'
# Rendering tree 21 for class 'UDP500Mbps'
# Rendering tree 22 for class 'UDP50Mbps'
# Rendering tree 23 for class 'UDP5Mbps'
# Rendering tree 24 for class 'TCP500Mbps'
# Rendering tree 25 for class 'TCP50Mbps'
# Rendering tree 26 for class 'TCP5Mbps'
# Rendering tree 27 for class 'UDP500Mbps'
# Rendering tree 28 for class 'UDP50Mbps'
# Rendering tree 29 for class 'UDP5Mbps'
# Rendering tree 30 for class 'TCP500Mbps'
# Rendering tree 31 for class 'TCP50Mbps'
# Rendering tree 32 for class 'TCP5Mbps'
# Rendering tree 33 for class 'UDP500Mbps'
# Rendering tree 34 for class 'UDP50Mbps'
# Rendering tree 35 for class 'UDP5Mbps'
# Rendering tree 36 for class 'TCP500Mbps'
# Rendering tree 37 for class 'TCP50Mbps'
# Rendering tree 38 for class 'TCP5Mbps'
# Rendering tree 39 for class 'UDP500Mbps'
# Rendering tree 40 for class 'UDP50Mbps'
# Rendering tree 41 for class 'UDP5Mbps'
# Rendering tree 42 for class 'TCP500Mbps'
# Rendering tree 43 for class 'TCP50Mbps'
# Rendering tree 44 for class 'TCP5Mbps'
# Rendering tree 45 for class 'UDP500Mbps'
# Rendering tree 46 for class 'UDP50Mbps'
# Rendering tree 47 for class 'UDP5Mbps'
# Rendering tree 48 for class 'TCP500Mbps'
# Rendering tree 49 for class 'TCP50Mbps'
# Rendering tree 50 for class 'TCP5Mbps'
# Rendering tree 51 for class 'UDP500Mbps'
# Rendering tree 52 for class 'UDP50Mbps'
# Rendering tree 53 for class 'UDP5Mbps'
# Rendering tree 54 for class 'TCP500Mbps'
# Rendering tree 55 for class 'TCP50Mbps'
# Rendering tree 56 for class 'TCP5Mbps'
# Rendering tree 57 for class 'UDP500Mbps'
# Rendering tree 58 for class 'UDP50Mbps'
# Rendering tree 59 for class 'UDP5Mbps'
# Rendering tree 60 for class 'TCP500Mbps'
# Rendering tree 61 for class 'TCP50Mbps'
# Rendering tree 62 for class 'TCP5Mbps'
# Rendering tree 63 for class 'UDP500Mbps'
# Rendering tree 64 for class 'UDP50Mbps'
# Rendering tree 65 for class 'UDP5Mbps'
# Rendering tree 66 for class 'TCP500Mbps'
# Rendering tree 67 for class 'TCP50Mbps'
# Rendering tree 68 for class 'TCP5Mbps'
# Rendering tree 69 for class 'UDP500Mbps'
# Rendering tree 70 for class 'UDP50Mbps'
# Rendering tree 71 for class 'UDP5Mbps'
# Rendering tree 72 for class 'TCP500Mbps'
# Rendering tree 73 for class 'TCP50Mbps'
# Rendering tree 74 for class 'TCP5Mbps'
# Rendering tree 75 for class 'UDP500Mbps'
# Rendering tree 76 for class 'UDP50Mbps'
# Rendering tree 77 for class 'UDP5Mbps'
# Rendering tree 78 for class 'TCP500Mbps'
# Rendering tree 79 for class 'TCP50Mbps'
# Rendering tree 80 for class 'TCP5Mbps'
# Rendering tree 81 for class 'UDP500Mbps'
# Rendering tree 82 for class 'UDP50Mbps'
# Rendering tree 83 for class 'UDP5Mbps'
# Rendering tree 84 for class 'TCP500Mbps'
# Rendering tree 85 for class 'TCP50Mbps'
# Rendering tree 86 for class 'TCP5Mbps'
# Rendering tree 87 for class 'UDP500Mbps'
# Rendering tree 88 for class 'UDP50Mbps'
# Rendering tree 89 for class 'UDP5Mbps'
# Rendering tree 90 for class 'TCP500Mbps'
# Rendering tree 91 for class 'TCP50Mbps'
# Rendering tree 92 for class 'TCP5Mbps'
# Rendering tree 93 for class 'UDP500Mbps'
# Rendering tree 94 for class 'UDP50Mbps'
# Rendering tree 95 for class 'UDP5Mbps'
# Rendering tree 96 for class 'TCP500Mbps'
# Rendering tree 97 for class 'TCP50Mbps'
# Rendering tree 98 for class 'TCP5Mbps'
# Rendering tree 99 for class 'UDP500Mbps'
# Rendering tree 100 for class 'UDP50Mbps'
# Rendering tree 101 for class 'UDP5Mbps'
# Rendering tree 102 for class 'TCP500Mbps'
# Rendering tree 103 for class 'TCP50Mbps'
# Rendering tree 104 for class 'TCP5Mbps'
# Rendering tree 105 for class 'UDP500Mbps'
# Rendering tree 106 for class 'UDP50Mbps'
# Rendering tree 107 for class 'UDP5Mbps'
# Rendering tree 108 for class 'TCP500Mbps'
# Rendering tree 109 for class 'TCP50Mbps'
# Rendering tree 110 for class 'TCP5Mbps'
# Rendering tree 111 for class 'UDP500Mbps'
# Rendering tree 112 for class 'UDP50Mbps'
# Rendering tree 113 for class 'UDP5Mbps'
# Rendering tree 114 for class 'TCP500Mbps'
# Rendering tree 115 for class 'TCP50Mbps'
# Rendering tree 116 for class 'TCP5Mbps'
# Rendering tree 117 for class 'UDP500Mbps'
# Rendering tree 118 for class 'UDP50Mbps'
# Rendering tree 119 for class 'UDP5Mbps'
#
# All trees have been rendered with class names in their filenames.
