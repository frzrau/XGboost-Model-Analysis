# %%
import pickle
import numpy as np
import pandas as pd

def load_data(trees_path: str, features_path: str):
    """Load the XGBoost tree dump and the feature CSV."""
    trees_df = pd.read_csv(trees_path)
    features_df = pd.read_csv(features_path)
    return trees_df, features_df

def build_tree_structures(trees_df: pd.DataFrame):
    """
    Build an in-memory dict of tree structures:
      { tree_index: { node_id: {feature, threshold, yes, no, missing, gain} } }
    """
    structures = {}
    for _, row in trees_df.iterrows():
        tree_idx = int(row['Tree'])
        node_id = int(row['Node'])
        structures.setdefault(tree_idx, {})[node_id] = {
            'feature': row['Feature'],
            'threshold': row['Split'],
            'yes': int(row['Yes'].split('-')[1]) if isinstance(row['Yes'], str) else None,
            'no':  int(row['No'].split('-')[1]) if isinstance(row['No'], str) else None,
            'missing': int(row['Missing'].split('-')[1]) if isinstance(row['Missing'], str) else None,
            'gain': row['Gain']
        }
    return structures

def generate_report_for_sample(tree_structures, sample: pd.Series):
    """
    Traverse each tree, recording Tree, Node, Feature, Threshold, SampleValue, and Result or leaf value.
    """
    rows = []
    for tree_idx, nodes in tree_structures.items():
        node_id = 0
        while True:
            node = nodes[node_id]
            feat = node['feature']
            if feat == 'Leaf':  # leaf node
                rows.append({
                    'Tree': tree_idx,
                    'Node': node_id,
                    'Feature': 'Leaf',
                    'Threshold': None,
                    'SampleValue': None,
                    'Result': node['gain']
                })
                break

            # decision node
            val = sample[feat]
            if pd.isna(val):
                branch, next_id = 'missing', node['missing']
            elif val < node['threshold']:
                branch, next_id = 'yes', node['yes']
            else:
                branch, next_id = 'no', node['no']

            rows.append({
                'Tree': tree_idx,
                'Node': node_id,
                'Feature': feat,
                'Threshold': node['threshold'],
                'SampleValue': val,
                'Result': branch
            })
            node_id = next_id

    return pd.DataFrame(rows).sort_values(['Tree', 'Node']).reset_index(drop=True)

def main():
    # File paths
    trees_csv = 'xgboost_trees.csv'
    features_csv = 'ns3_features_50Mbps.csv'
    labelenc_pkl = 'label_encoder.pkl'

    # Load LabelEncoder
    with open(labelenc_pkl, 'rb') as f:
        le_obj = pickle.load(f)
    classes = le_obj.classes_ if hasattr(le_obj, 'classes_') else np.array(le_obj)
    num_classes = len(classes)

    # Load data
    trees_df, features_df = load_data(trees_csv, features_csv)
    tree_structures = build_tree_structures(trees_df)

    # Select a sample
    sample_idx = 1
    sample = features_df.iloc[sample_idx]

    # Generate node-by-node report
    report_df = generate_report_for_sample(tree_structures, sample)
    report_df['Class'] = report_df['Tree'].apply(lambda t: classes[t % num_classes])

    # Print detailed report
    pd.set_option('display.max_rows', None)
    print(f"\nNode-by-node report for sample {sample_idx}:\n")
    print(report_df)

    # Extract leaf outputs and compute class scores
    leaf_df = report_df[report_df['Feature'] == 'Leaf'][['Class', 'Result']]
    # Ensure numeric type for scores
    scores = leaf_df.groupby('Class')['Result'].sum().astype(float)

    # Softmax probabilities (vectorized)
    exp_vals = np.exp(scores.values)
    prob_vals = exp_vals / exp_vals.sum()
    # Create Series with same index
    probs = pd.Series(prob_vals, index=scores.index)

    # Display computation details
    print("\nCalculation of class scores and probabilities:")
    for cls in classes:
        raw = scores.get(cls, 0.0)
        p = probs.get(cls, 0.0)
        print(f"  Class {cls}:")
        print(f"    - Sum of leaf values = {raw}")
        print(f"    - Probability (softmax) = {p:.4f}")

    # Predicted class = highest probability
    pred = probs.idxmax()
    print(f"\nPredicted class for sample {sample_idx}: {pred}\n")

    # Save report
    out_csv = f'detailed_report_sample_{sample_idx}.csv'
    report_df.to_csv(out_csv, index=False)
    print(f"Report saved to '{out_csv}'")

if __name__ == '__main__':
    main()
# Out:
# Node-by-node report for sample 1:
#
#      Tree  Node              Feature     Threshold   SampleValue    Result  \
# 0       0     0   iat_variance_ratio  3.713158e-05  3.530000e-05       yes
# 1       0     1                 Leaf           NaN           NaN -0.005852
# 2       1     0  reverse_num_packets  1.031200e+04  1.041700e+04        no
# 3       1     2  reverse_num_packets  9.529000e+04  1.041700e+04       yes
# 4       1     3                 Leaf           NaN           NaN  0.027202
# 5       2     0            avg_bytes  3.016637e+07  3.102692e+07        no
# 6       2     2                 Leaf           NaN           NaN -0.005841
# 7       3     0                bytes  3.016575e+08  3.073015e+07       yes
# 8       3     1                 Leaf           NaN           NaN -0.005882
# 9       4     0             duration  5.000040e+00  4.999996e+00       yes
# 10      4     1             duration  4.998480e+00  4.999996e+00        no
# 11      4     4             duration  4.999924e+00  4.999996e+00        no
# 12      4    10                 Leaf           NaN           NaN -0.005725
# 13      5     0             protocol  1.000000e+00  0.000000e+00       yes
# 14      5     1                 Leaf           NaN           NaN -0.005824
# 15      6     0              std_iat  2.163066e-05  7.510000e-05        no
# 16      6     2              std_iat  2.604304e-05  7.510000e-05        no
# 17      6     4           burstiness -2.283500e-01 -1.993371e-01        no
# 18      6     6                 Leaf           NaN           NaN -0.004681
# 19      7     0              std_iat  4.807276e-05  7.510000e-05        no
# 20      7     2          total_bytes  3.015750e+07  3.131350e+07        no
# 21      7     4          total_bytes  3.137606e+07  3.131350e+07       yes
# 22      7     5                 Leaf           NaN           NaN  0.026556
# 23      8     0     avg_dt_intensity  6.396967e+11  9.608320e+11        no
# 24      8     2                 Leaf           NaN           NaN  -0.00584
# 25      9     0                bytes  3.016575e+08  3.073015e+07       yes
# 26      9     1                 Leaf           NaN           NaN -0.005874
# 27     10     0           directions  1.000000e+00  6.666667e-01       yes
# 28     10     1                 Leaf           NaN           NaN -0.005818
# 29     11     0          total_bytes  3.099454e+06  3.131350e+07        no
# 30     11     2                 Leaf           NaN           NaN -0.005877
# 31     12     0          packet_rate  5.718075e+04  6.250205e+03       yes
# 32     12     1                 Leaf           NaN           NaN -0.005858
# 33     13     0        total_packets  3.093700e+04  3.125100e+04        no
# 34     13     2        total_packets  6.250400e+04  3.125100e+04       yes
# 35     13     3         max_pkt_size  7.250000e+02  1.475000e+03        no
# 36     13     6                 Leaf           NaN           NaN  0.026005
# 37     14     0             protocol  1.000000e+00  0.000000e+00       yes
# 38     14     1  reverse_num_packets  1.031200e+04  1.041700e+04        no
# 39     14     4                 Leaf           NaN           NaN -0.005713
# 40     15     0         std_pkt_size  3.153408e+02  6.689230e+02        no
# 41     15     2                 Leaf           NaN           NaN -0.005789
# 42     16     0         dt_intensity  1.921428e+12  9.785470e+11       yes
# 43     16     1         dt_intensity  6.387235e+11  9.785470e+11        no
# 44     16     4         dt_intensity  1.256150e+12  9.785470e+11       yes
# 45     16     5                 Leaf           NaN           NaN  0.009183
# 46     17     0              std_iat  3.547189e-15  7.510000e-05        no
# 47     17     2                 Leaf           NaN           NaN -0.005793
# 48     18     0             mean_iat  2.400000e-05  1.600000e-04        no
# 49     18     2                 Leaf           NaN           NaN -0.005848
# 50     19     0     avg_dt_intensity  9.588637e+11  9.608320e+11        no
# 51     19     2     avg_dt_intensity  6.397509e+13  9.608320e+11       yes
# 52     19     3     avg_dt_intensity  1.921428e+12  9.608320e+11       yes
# 53     19     5                 Leaf           NaN           NaN  0.010114
# 54     20     0              min_iat  4.970000e-04  0.000000e+00       yes
# 55     20     1        mean_pkt_size  5.019821e+02  1.002000e+03        no
# 56     20     4                 Leaf           NaN           NaN -0.005348
# 57     21     0             mean_iat  7.999616e-05  1.600000e-04        no
# 58     21     2                 Leaf           NaN           NaN -0.005832
# 59     22     0   iat_variance_ratio  2.621365e-25  3.530000e-05        no
# 60     22     2                 Leaf           NaN           NaN -0.005818
# 61     23     0            byte_rate  6.199646e+05  6.262705e+06        no
# 62     23     2                 Leaf           NaN           NaN -0.005869
# 63     24     0          packet_rate  5.718075e+04  6.250205e+03       yes
# 64     24     1                 Leaf           NaN           NaN -0.005846
# 65     25     0             mean_iat  2.400000e-04  1.600000e-04       yes
# 66     25     1             mean_iat  7.999616e-05  1.600000e-04        no
# 67     25     4             mean_iat  1.599949e-04  1.600000e-04        no
# 68     25     6                 Leaf           NaN           NaN  0.023317
# 69     26     0     avg_dt_intensity  6.396967e+11  9.608320e+11        no
# 70     26     2                 Leaf           NaN           NaN -0.005821
# 71     27     0          packet_rate  4.166687e+04  6.250205e+03       yes
# 72     27     1                 Leaf           NaN           NaN -0.005829
# 73     28     0         dt_intensity  1.921428e+12  9.785470e+11       yes
# 74     28     1         dt_intensity  6.387235e+11  9.785470e+11        no
# 75     28     4         dt_intensity  1.256150e+12  9.785470e+11       yes
# 76     28     5                 Leaf           NaN           NaN   0.00963
# 77     29     0  reverse_num_packets  1.033000e+03  1.041700e+04        no
# 78     29     2                 Leaf           NaN           NaN -0.005785
# 79     30     0           directions  1.000000e+00  6.666667e-01       yes
# 80     30     1              max_iat  1.200000e-03  2.400000e-04       yes
# 81     30     3              max_iat  4.000000e-04  2.400000e-04       yes
# 82     30     5                 Leaf           NaN           NaN -0.005352
# 83     31     0          packet_rate  6.187542e+03  6.250205e+03        no
# 84     31     2                bytes  2.417927e+08  3.073015e+07       yes
# 85     31     3                bytes  3.019988e+07  3.073015e+07        no
# 86     31     6                 Leaf           NaN           NaN  0.024674
# 87     32     0        mean_pkt_size  5.020032e+02  1.002000e+03        no
# 88     32     2     avg_max_pkt_size  1.475000e+03  1.475000e+03        no
# 89     32     6        mean_pkt_size  1.002015e+03  1.002000e+03       yes
# 90     32    11                 Leaf           NaN           NaN  0.008285
# 91     33     0             protocol  1.000000e+00  0.000000e+00       yes
# 92     33     1                 Leaf           NaN           NaN -0.005772
# 93     34     0  reverse_num_packets  1.033000e+03  1.041700e+04        no
# 94     34     2                 Leaf           NaN           NaN -0.005768
# 95     35     0            byte_rate  6.199646e+05  6.262705e+06        no
# 96     35     2                 Leaf           NaN           NaN -0.005857
# 97     36     0         min_pkt_size  7.240000e+02  5.600000e+01       yes
# 98     36     1                 Leaf           NaN           NaN  0.005885
# 99     37     0       tcp_flag_count  3.093900e+04  3.125100e+04        no
# 100    37     2       tcp_flag_count  2.859050e+05  3.125100e+04       yes
# 101    37     3                 Leaf           NaN           NaN  0.024205
# 102    38     0          packet_rate  4.166867e+03  6.250205e+03        no
# 103    38     2                 Leaf           NaN           NaN -0.005814
# 104    39     0             protocol  1.000000e+00  0.000000e+00       yes
# 105    39     1                 Leaf           NaN           NaN  -0.00575
# 106    40     0            byte_rate  6.199158e+06  6.262705e+06        no
# 107    40     2                 Leaf           NaN           NaN -0.005769
# 108    41     0   iat_variance_ratio  1.155831e-26  3.530000e-05        no
# 109    41     2                 Leaf           NaN           NaN -0.005837
# 110    42     0         min_pkt_size  7.240000e+02  5.600000e+01       yes
# 111    42     1              std_iat  4.807276e-05  7.510000e-05        no
# 112    42     4         min_pkt_size  5.600000e+01  5.600000e+01        no
# 113    42     6                 Leaf           NaN           NaN -0.005661
# 114    43     0        total_packets  3.093700e+04  3.125100e+04        no
# 115    43     2        total_packets  2.083170e+05  3.125100e+04       yes
# 116    43     3        total_packets  4.165400e+04  3.125100e+04       yes
# 117    43     5                 Leaf           NaN           NaN  0.021984
# 118    44     0              std_iat  2.863373e-04  7.510000e-05       yes
# 119    44     1                 Leaf           NaN           NaN -0.005831
# 120    45     0             duration  5.000025e+00  4.999996e+00       yes
# 121    45     1             duration  4.999992e+00  4.999996e+00        no
# 122    45     4                 Leaf           NaN           NaN  0.013228
# 123    46     0         std_pkt_size  3.153408e+02  6.689230e+02        no
# 124    46     2                 Leaf           NaN           NaN -0.005768
# 125    47     0   iat_variance_ratio  1.155831e-26  3.530000e-05        no
# 126    47     2                 Leaf           NaN           NaN -0.005832
# 127    48     0          packet_rate  5.718075e+04  6.250205e+03       yes
# 128    48     1                 Leaf           NaN           NaN -0.005817
# 129    49     0              max_iat  4.000000e-04  2.400000e-04       yes
# 130    49     1         rms_pkt_size  5.928571e+02  1.204766e+03        no
# 131    49     4              max_iat  2.400000e-04  2.400000e-04        no
# 132    49     8                 Leaf           NaN           NaN  0.008928
# 133    50     0          packet_rate  4.166867e+03  6.250205e+03        no
# 134    50     2                 Leaf           NaN           NaN -0.005801
# 135    51     0             mean_iat  7.999616e-05  1.600000e-04        no
# 136    51     2                 Leaf           NaN           NaN -0.005814
# 137    52     0              max_iat  4.000000e-04  2.400000e-04       yes
# 138    52     1              max_iat  1.200000e-04  2.400000e-04        no
# 139    52     4        mean_pkt_size  5.020224e+02  1.002000e+03        no
# 140    52     6                 Leaf           NaN           NaN  0.014528
# 141    53     0                bytes  3.073900e+06  3.073015e+07        no
# 142    53     2                 Leaf           NaN           NaN -0.005825
# 143    54     0                bytes  2.417927e+08  3.073015e+07       yes
# 144    54     1                 Leaf           NaN           NaN -0.005793
# 145    55     0       tcp_flag_count  3.093900e+04  3.125100e+04        no
# 146    55     2       tcp_flag_count  2.859050e+05  3.125100e+04       yes
# 147    55     3                 Leaf           NaN           NaN  0.022844
# 148    56     0              max_iat  9.700000e-04  2.400000e-04       yes
# 149    56     1                 Leaf           NaN           NaN -0.005768
# 150    57     0              max_iat  1.200000e-04  2.400000e-04        no
# 151    57     2                 Leaf           NaN           NaN  -0.00584
# 152    58     0       tcp_flag_count  3.100000e+03  3.125100e+04        no
# 153    58     2                 Leaf           NaN           NaN -0.005755
# 154    59     0            avg_bytes  3.099454e+06  3.102692e+07        no
# 155    59     2                 Leaf           NaN           NaN -0.005837
# 156    60     0   iat_variance_ratio  3.713158e-05  3.530000e-05       yes
# 157    60     1                 Leaf           NaN           NaN -0.005787
# 158    61     0   iat_variance_ratio  2.888715e-05  3.530000e-05        no
# 159    61     2   iat_variance_ratio  3.713158e-05  3.530000e-05       yes
# 160    61     3                 Leaf           NaN           NaN  0.022285
# 161    62     0         rms_pkt_size  5.928444e+02  1.204766e+03        no
# 162    62     2         rms_pkt_size  1.204776e+03  1.204766e+03       yes
# 163    62     5         rms_pkt_size  1.204766e+03  1.204766e+03        no
# 164    62    10                 Leaf           NaN           NaN  0.010427
# 165    63     0       tcp_flag_count  3.100000e+03  3.125100e+04        no
# 166    63     2                 Leaf           NaN           NaN -0.005733
# 167    64     0              min_iat  1.200000e-04  0.000000e+00       yes
# 168    64     1                 Leaf           NaN           NaN -0.005765
# 169    65     0              std_iat  3.547189e-15  7.510000e-05        no
# 170    65     2                 Leaf           NaN           NaN  -0.00575
# 171    66     0        total_packets  2.859030e+05  3.125100e+04       yes
# 172    66     1                 Leaf           NaN           NaN   -0.0058
# 173    67     0     avg_min_pkt_size  7.240000e+02  4.520000e+01       yes
# 174    67     1        total_packets  2.081700e+04  3.125100e+04        no
# 175    67     4        total_packets  2.083170e+05  3.125100e+04       yes
# 176    67     5                 Leaf           NaN           NaN  0.022178
# 177    68     0             duration  4.999464e+00  4.999996e+00        no
# 178    68     2             duration  5.000400e+00  4.999996e+00       yes
# 179    68     5                 Leaf           NaN           NaN -0.005776
# 180    69     0             protocol  1.000000e+00  0.000000e+00       yes
# 181    69     1                 Leaf           NaN           NaN -0.005729
# 182    70     0        reverse_bytes  5.784000e+04  5.833520e+05        no
# 183    70     2                 Leaf           NaN           NaN -0.005737
# 184    71     0         std_pkt_size  3.153408e+02  6.689230e+02        no
# 185    71     2                 Leaf           NaN           NaN -0.005719
# 186    72     0  reverse_num_packets  9.529000e+04  1.041700e+04       yes
# 187    72     1                 Leaf           NaN           NaN -0.005809
# 188    73     0  reverse_num_packets  1.031200e+04  1.041700e+04        no
# 189    73     2  reverse_num_packets  9.529000e+04  1.041700e+04       yes
# 190    73     3                 Leaf           NaN           NaN  0.021466
# 191    74     0  reverse_num_packets  1.033000e+03  1.041700e+04        no
# 192    74     2  reverse_num_packets  1.031200e+04  1.041700e+04        no
# 193    74     4                 Leaf           NaN           NaN -0.005594
# 194    75     0            avg_bytes  3.016664e+08  3.102692e+07       yes
# 195    75     1                 Leaf           NaN           NaN -0.005827
# 196    76     0     avg_min_pkt_size  7.240000e+02  4.520000e+01       yes
# 197    76     1                 Leaf           NaN           NaN -0.005723
# 198    77     0        total_packets  6.191000e+03  3.125100e+04        no
# 199    77     2                 Leaf           NaN           NaN -0.005815
# 200    78     0     avg_dt_intensity  6.397617e+13  9.608320e+11       yes
# 201    78     1                 Leaf           NaN           NaN -0.005775
# 202    79     0             protocol  1.000000e+00  0.000000e+00       yes
# 203    79     1        mean_pkt_size  1.002031e+03  1.002000e+03       yes
# 204    79     3        mean_pkt_size  5.019973e+02  1.002000e+03        no
# 205    79     6                 Leaf           NaN           NaN   0.00543
# 206    80     0                bytes  2.990206e+07  3.073015e+07        no
# 207    80     2                 Leaf           NaN           NaN -0.005767
# 208    81     0            avg_bytes  3.016664e+08  3.102692e+07       yes
# 209    81     1                 Leaf           NaN           NaN -0.005813
# 210    82     0              min_iat  1.200000e-04  0.000000e+00       yes
# 211    82     1                 Leaf           NaN           NaN -0.005732
# 212    83     0        reverse_bytes  5.784000e+04  5.833520e+05        no
# 213    83     2                 Leaf           NaN           NaN -0.005718
# 214    84     0             mean_iat  2.400000e-05  1.600000e-04        no
# 215    84     2                 Leaf           NaN           NaN  -0.00578
# 216    85     0            avg_bytes  3.099508e+07  3.102692e+07        no
# 217    85     2            avg_bytes  2.511256e+08  3.102692e+07       yes
# 218    85     3                 Leaf           NaN           NaN   0.02092
# 219    86     0                bytes  2.990206e+07  3.073015e+07        no
# 220    86     2                 Leaf           NaN           NaN -0.005769
# 221    87     0            avg_bytes  3.016664e+08  3.102692e+07       yes
# 222    87     1                 Leaf           NaN           NaN -0.005812
# 223    88     0          total_bytes  3.099508e+07  3.131350e+07        no
# 224    88     2                 Leaf           NaN           NaN -0.005725
# 225    89     0          packet_rate  1.238347e+03  6.250205e+03        no
# 226    89     2                 Leaf           NaN           NaN -0.005803
# 227    90     0         dt_intensity  8.190696e+13  9.785470e+11       yes
# 228    90     1                 Leaf           NaN           NaN -0.005762
# 229    91     0              min_iat  1.200000e-05  0.000000e+00       yes
# 230    91     1         dt_intensity  1.961101e+12  9.785470e+11       yes
# 231    91     3         dt_intensity  9.775304e+11  9.785470e+11        no
# 232    91     6                 Leaf           NaN           NaN  0.020435
# 233    92     0     avg_dt_intensity  6.396967e+11  9.608320e+11        no
# 234    92     2                 Leaf           NaN           NaN -0.005755
# 235    93     0        reverse_bytes  5.784000e+04  5.833520e+05        no
# 236    93     2                 Leaf           NaN           NaN -0.005685
# 237    94     0  reverse_num_packets  1.033000e+03  1.041700e+04        no
# 238    94     2                 Leaf           NaN           NaN -0.005721
# 239    95     0             protocol  1.000000e+00  0.000000e+00       yes
# 240    95     1                 Leaf           NaN           NaN -0.005705
# 241    96     0  reverse_num_packets  9.529000e+04  1.041700e+04       yes
# 242    96     1                 Leaf           NaN           NaN -0.005783
# 243    97     0              std_iat  4.807276e-05  7.510000e-05        no
# 244    97     2              std_iat  2.863373e-04  7.510000e-05       yes
# 245    97     3         min_pkt_size  5.600000e+01  5.600000e+01        no
# 246    97     6                 Leaf           NaN           NaN  0.020001
# 247    98     0            avg_bytes  3.016637e+07  3.102692e+07        no
# 248    98     2                 Leaf           NaN           NaN -0.005744
# 249    99     0         std_pkt_size  3.153408e+02  6.689230e+02        no
# 250    99     2                 Leaf           NaN           NaN -0.005696
# 251   100     0             protocol  1.000000e+00  0.000000e+00       yes
# 252   100     1                 Leaf           NaN           NaN -0.005698
# 253   101     0        total_packets  6.191000e+03  3.125100e+04        no
# 254   101     2                 Leaf           NaN           NaN -0.005784
# 255   102     0             mean_iat  2.400000e-05  1.600000e-04        no
# 256   102     2                 Leaf           NaN           NaN -0.005765
# 257   103     0        reverse_bytes  5.774640e+05  5.833520e+05        no
# 258   103     2        reverse_bytes  5.336232e+06  5.833520e+05       yes
# 259   103     3                 Leaf           NaN           NaN  0.019733
# 260   104     0              std_iat  2.863373e-04  7.510000e-05       yes
# 261   104     1                 Leaf           NaN           NaN -0.005769
# 262   105     0  reverse_num_packets  1.033000e+03  1.041700e+04        no
# 263   105     2                 Leaf           NaN           NaN -0.005687
# 264   106     0             protocol  1.000000e+00  0.000000e+00       yes
# 265   106     1                 Leaf           NaN           NaN -0.005695
# 266   107     0          num_packets  2.062500e+04  2.083400e+04        no
# 267   107     2                 Leaf           NaN           NaN -0.005779
# 268   108     0            byte_rate  5.022688e+07  6.262705e+06       yes
# 269   108     1                 Leaf           NaN           NaN -0.005733
# 270   109     0              min_iat  1.200000e-05  0.000000e+00       yes
# 271   109     1            byte_rate  5.022688e+07  6.262705e+06       yes
# 272   109     3            byte_rate  6.264846e+05  6.262705e+06        no
# 273   109     6                 Leaf           NaN           NaN  0.019488
# 274   110     0     avg_min_pkt_size  7.240000e+02  4.520000e+01       yes
# 275   110     1      switching_ratio  1.292992e-04  0.000000e+00       yes
# 276   110     3     avg_min_pkt_size  4.520000e+01  4.520000e+01       yes
# 277   110     5                 Leaf           NaN           NaN -0.003604
# 278   111     0          num_packets  2.083170e+05  2.083400e+04       yes
# 279   111     1                 Leaf           NaN           NaN -0.005784
# 280   112     0          total_bytes  3.099508e+07  3.131350e+07        no
# 281   112     2                 Leaf           NaN           NaN -0.005722
# 282   113     0     avg_dt_intensity  1.922391e+10  9.608320e+11        no
# 283   113     2                 Leaf           NaN           NaN -0.005772
# 284   114     0           burstiness -2.284508e-01 -1.993371e-01        no
# 285   114     2           burstiness -1.993371e-01 -1.993371e-01        no
# 286   114     4           burstiness -1.993359e-01 -1.993371e-01       yes
# 287   114     7                 Leaf           NaN           NaN  -0.00504
# 288   115     0          packet_rate  6.187542e+03  6.250205e+03        no
# 289   115     2          packet_rate  4.166687e+04  6.250205e+03       yes
# 290   115     3         max_pkt_size  7.250000e+02  1.475000e+03        no
# 291   115     6                 Leaf           NaN           NaN  0.019134
# 292   116     0        total_packets  2.081700e+04  3.125100e+04        no
# 293   116     2                 Leaf           NaN           NaN -0.005743
# 294   117     0         std_pkt_size  3.153408e+02  6.689230e+02        no
# 295   117     2                 Leaf           NaN           NaN  -0.00568
# 296   118     0          total_bytes  3.099508e+07  3.131350e+07        no
# 297   118     2                 Leaf           NaN           NaN -0.005705
# 298   119     0            byte_rate  6.199646e+05  6.262705e+06        no
# 299   119     2                 Leaf           NaN           NaN -0.005784
#
#           Class
# 0    TCP500Mbps
# 1    TCP500Mbps
# 2     TCP50Mbps
# 3     TCP50Mbps
# 4     TCP50Mbps
# 5      TCP5Mbps
# 6      TCP5Mbps
# 7    UDP500Mbps
# 8    UDP500Mbps
# 9     UDP50Mbps
# 10    UDP50Mbps
# 11    UDP50Mbps
# 12    UDP50Mbps
# 13     UDP5Mbps
# 14     UDP5Mbps
# 15   TCP500Mbps
# 16   TCP500Mbps
# 17   TCP500Mbps
# 18   TCP500Mbps
# 19    TCP50Mbps
# 20    TCP50Mbps
# 21    TCP50Mbps
# 22    TCP50Mbps
# 23     TCP5Mbps
# 24     TCP5Mbps
# 25   UDP500Mbps
# 26   UDP500Mbps
# 27    UDP50Mbps
# 28    UDP50Mbps
# 29     UDP5Mbps
# 30     UDP5Mbps
# 31   TCP500Mbps
# 32   TCP500Mbps
# 33    TCP50Mbps
# 34    TCP50Mbps
# 35    TCP50Mbps
# 36    TCP50Mbps
# 37     TCP5Mbps
# 38     TCP5Mbps
# 39     TCP5Mbps
# 40   UDP500Mbps
# 41   UDP500Mbps
# 42    UDP50Mbps
# 43    UDP50Mbps
# 44    UDP50Mbps
# 45    UDP50Mbps
# 46     UDP5Mbps
# 47     UDP5Mbps
# 48   TCP500Mbps
# 49   TCP500Mbps
# 50    TCP50Mbps
# 51    TCP50Mbps
# 52    TCP50Mbps
# 53    TCP50Mbps
# 54     TCP5Mbps
# 55     TCP5Mbps
# 56     TCP5Mbps
# 57   UDP500Mbps
# 58   UDP500Mbps
# 59    UDP50Mbps
# 60    UDP50Mbps
# 61     UDP5Mbps
# 62     UDP5Mbps
# 63   TCP500Mbps
# 64   TCP500Mbps
# 65    TCP50Mbps
# 66    TCP50Mbps
# 67    TCP50Mbps
# 68    TCP50Mbps
# 69     TCP5Mbps
# 70     TCP5Mbps
# 71   UDP500Mbps
# 72   UDP500Mbps
# 73    UDP50Mbps
# 74    UDP50Mbps
# 75    UDP50Mbps
# 76    UDP50Mbps
# 77     UDP5Mbps
# 78     UDP5Mbps
# 79   TCP500Mbps
# 80   TCP500Mbps
# 81   TCP500Mbps
# 82   TCP500Mbps
# 83    TCP50Mbps
# 84    TCP50Mbps
# 85    TCP50Mbps
# 86    TCP50Mbps
# 87     TCP5Mbps
# 88     TCP5Mbps
# 89     TCP5Mbps
# 90     TCP5Mbps
# 91   UDP500Mbps
# 92   UDP500Mbps
# 93    UDP50Mbps
# 94    UDP50Mbps
# 95     UDP5Mbps
# 96     UDP5Mbps
# 97   TCP500Mbps
# 98   TCP500Mbps
# 99    TCP50Mbps
# 100   TCP50Mbps
# 101   TCP50Mbps
# 102    TCP5Mbps
# 103    TCP5Mbps
# 104  UDP500Mbps
# 105  UDP500Mbps
# 106   UDP50Mbps
# 107   UDP50Mbps
# 108    UDP5Mbps
# 109    UDP5Mbps
# 110  TCP500Mbps
# 111  TCP500Mbps
# 112  TCP500Mbps
# 113  TCP500Mbps
# 114   TCP50Mbps
# 115   TCP50Mbps
# 116   TCP50Mbps
# 117   TCP50Mbps
# 118    TCP5Mbps
# 119    TCP5Mbps
# 120  UDP500Mbps
# 121  UDP500Mbps
# 122  UDP500Mbps
# 123   UDP50Mbps
# 124   UDP50Mbps
# 125    UDP5Mbps
# 126    UDP5Mbps
# 127  TCP500Mbps
# 128  TCP500Mbps
# 129   TCP50Mbps
# 130   TCP50Mbps
# 131   TCP50Mbps
# 132   TCP50Mbps
# 133    TCP5Mbps
# 134    TCP5Mbps
# 135  UDP500Mbps
# 136  UDP500Mbps
# 137   UDP50Mbps
# 138   UDP50Mbps
# 139   UDP50Mbps
# 140   UDP50Mbps
# 141    UDP5Mbps
# 142    UDP5Mbps
# 143  TCP500Mbps
# 144  TCP500Mbps
# 145   TCP50Mbps
# 146   TCP50Mbps
# 147   TCP50Mbps
# 148    TCP5Mbps
# 149    TCP5Mbps
# 150  UDP500Mbps
# 151  UDP500Mbps
# 152   UDP50Mbps
# 153   UDP50Mbps
# 154    UDP5Mbps
# 155    UDP5Mbps
# 156  TCP500Mbps
# 157  TCP500Mbps
# 158   TCP50Mbps
# 159   TCP50Mbps
# 160   TCP50Mbps
# 161    TCP5Mbps
# 162    TCP5Mbps
# 163    TCP5Mbps
# 164    TCP5Mbps
# 165  UDP500Mbps
# 166  UDP500Mbps
# 167   UDP50Mbps
# 168   UDP50Mbps
# 169    UDP5Mbps
# 170    UDP5Mbps
# 171  TCP500Mbps
# 172  TCP500Mbps
# 173   TCP50Mbps
# 174   TCP50Mbps
# 175   TCP50Mbps
# 176   TCP50Mbps
# 177    TCP5Mbps
# 178    TCP5Mbps
# 179    TCP5Mbps
# 180  UDP500Mbps
# 181  UDP500Mbps
# 182   UDP50Mbps
# 183   UDP50Mbps
# 184    UDP5Mbps
# 185    UDP5Mbps
# 186  TCP500Mbps
# 187  TCP500Mbps
# 188   TCP50Mbps
# 189   TCP50Mbps
# 190   TCP50Mbps
# 191    TCP5Mbps
# 192    TCP5Mbps
# 193    TCP5Mbps
# 194  UDP500Mbps
# 195  UDP500Mbps
# 196   UDP50Mbps
# 197   UDP50Mbps
# 198    UDP5Mbps
# 199    UDP5Mbps
# 200  TCP500Mbps
# 201  TCP500Mbps
# 202   TCP50Mbps
# 203   TCP50Mbps
# 204   TCP50Mbps
# 205   TCP50Mbps
# 206    TCP5Mbps
# 207    TCP5Mbps
# 208  UDP500Mbps
# 209  UDP500Mbps
# 210   UDP50Mbps
# 211   UDP50Mbps
# 212    UDP5Mbps
# 213    UDP5Mbps
# 214  TCP500Mbps
# 215  TCP500Mbps
# 216   TCP50Mbps
# 217   TCP50Mbps
# 218   TCP50Mbps
# 219    TCP5Mbps
# 220    TCP5Mbps
# 221  UDP500Mbps
# 222  UDP500Mbps
# 223   UDP50Mbps
# 224   UDP50Mbps
# 225    UDP5Mbps
# 226    UDP5Mbps
# 227  TCP500Mbps
# 228  TCP500Mbps
# 229   TCP50Mbps
# 230   TCP50Mbps
# 231   TCP50Mbps
# 232   TCP50Mbps
# 233    TCP5Mbps
# 234    TCP5Mbps
# 235  UDP500Mbps
# 236  UDP500Mbps
# 237   UDP50Mbps
# 238   UDP50Mbps
# 239    UDP5Mbps
# 240    UDP5Mbps
# 241  TCP500Mbps
# 242  TCP500Mbps
# 243   TCP50Mbps
# 244   TCP50Mbps
# 245   TCP50Mbps
# 246   TCP50Mbps
# 247    TCP5Mbps
# 248    TCP5Mbps
# 249  UDP500Mbps
# 250  UDP500Mbps
# 251   UDP50Mbps
# 252   UDP50Mbps
# 253    UDP5Mbps
# 254    UDP5Mbps
# 255  TCP500Mbps
# 256  TCP500Mbps
# 257   TCP50Mbps
# 258   TCP50Mbps
# 259   TCP50Mbps
# 260    TCP5Mbps
# 261    TCP5Mbps
# 262  UDP500Mbps
# 263  UDP500Mbps
# 264   UDP50Mbps
# 265   UDP50Mbps
# 266    UDP5Mbps
# 267    UDP5Mbps
# 268  TCP500Mbps
# 269  TCP500Mbps
# 270   TCP50Mbps
# 271   TCP50Mbps
# 272   TCP50Mbps
# 273   TCP50Mbps
# 274    TCP5Mbps
# 275    TCP5Mbps
# 276    TCP5Mbps
# 277    TCP5Mbps
# 278  UDP500Mbps
# 279  UDP500Mbps
# 280   UDP50Mbps
# 281   UDP50Mbps
# 282    UDP5Mbps
# 283    UDP5Mbps
# 284  TCP500Mbps
# 285  TCP500Mbps
# 286  TCP500Mbps
# 287  TCP500Mbps
# 288   TCP50Mbps
# 289   TCP50Mbps
# 290   TCP50Mbps
# 291   TCP50Mbps
# 292    TCP5Mbps
# 293    TCP5Mbps
# 294  UDP500Mbps
# 295  UDP500Mbps
# 296   UDP50Mbps
# 297   UDP50Mbps
# 298    UDP5Mbps
# 299    UDP5Mbps
#
# Calculation of class scores and probabilities:
#   Class TCP500Mbps:
#     - Sum of leaf values = -0.10185821680000001
#     - Probability (softmax) = 0.1490
#   Class TCP50Mbps:
#     - Sum of leaf values = 0.40689908857999996
#     - Probability (softmax) = 0.2478
#   Class TCP5Mbps:
#     - Sum of leaf values = -0.08258685054
#     - Probability (softmax) = 0.1519
#   Class UDP500Mbps:
#     - Sum of leaf values = -0.09660252274
#     - Probability (softmax) = 0.1498
#   Class UDP50Mbps:
#     - Sum of leaf values = -0.06430394022
#     - Probability (softmax) = 0.1547
#   Class UDP5Mbps:
#     - Sum of leaf values = -0.11596584647000001
#     - Probability (softmax) = 0.1469
#
# Predicted class for sample 1: TCP50Mbps
#
# Report saved to 'detailed_report_sample_1.csv'
